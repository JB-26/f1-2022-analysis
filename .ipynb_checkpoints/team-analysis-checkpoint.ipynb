# %% [markdown]
# # Team Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf

# %%
# %matplotlib inline

# %%
sns.set_theme()

# %%
# create dataframe and remove extra column
raceResults = pd.read_csv('data/compiled-data/race-results.csv')
raceResults.head()
# Out:
#   POS           Driver           Car  Laps Time/Retired  PTS     Race
# 0   1  Charles Leclerc       Ferrari    57      37:33.6   26  BAHRAIN
# 1   2     Carlos Sainz       Ferrari    57      +5.598s   18  BAHRAIN
# 2   3   Lewis Hamilton      Mercedes    57      +9.675s   15  BAHRAIN
# 3   4   George Russell      Mercedes    57     +11.211s   12  BAHRAIN
# 4   5  Kevin Magnussen  Haas Ferrari    57     +14.754s   10  BAHRAIN

# %%
raceResults.describe()
# Out:
#              Laps         PTS
# count  440.000000  440.000000
# mean    53.475000    5.095455
# std     17.306017    7.263663
# min      0.000000    0.000000
# 25%     50.000000    0.000000
# 50%     57.000000    0.500000
# 75%     66.000000    9.250000
# max     72.000000   26.000000

# %%
teamNameArray = ['Ferrari', 'Red Bull Racing RBPT', 'Mercedes', 'McLaren Mercedes', 'Alpine Renault', 'Alfa Romeo Ferrari', 'AlphaTauri RBPT', 'Williams Mercedes', 'Aston Martin Aramco Mercedes', 'Haas Ferrari']
len(teamNameArray)
# Out:
# 10

# %%
driverNameArray = ['Max Verstappen', 'Charles Leclerc', 'Sergio Perez', 'Carlos Sainz', 'George Russell', 'Lando Norris', 'Esteban Ocon', 'Lance Stroll', 'Daniel Ricciardo', 'Sebastian Vettel', 'Yuki Tsunoda', 'Zhou Guanyu', 'Alexander Albon', 'Pierre Gasly', 'Valtteri Bottas', 'Mick Schumacher', 'Kevin Magnussen', 'Lewis Hamilton', 'Nicholas Latifi', 'Fernando Alonso']

# %% [markdown]
# # Average number of points per race

# %%
avgPoints = pd.DataFrame()
avgPoints = avgPoints.assign(Team = '', AvgPoints = '')
avgPoints.head()
# Out:
# Empty DataFrame
# Columns: [Team, AvgPoints]
# Index: []

# %%
for i in teamNameArray:
    testRes = round(raceResults.loc[raceResults['Car'] == i]['PTS'].mean(), 2)
    avgPoints.loc[-1] = [i, testRes]
    avgPoints.index = avgPoints.index + 1

avgPoints.sort_values(by='AvgPoints', inplace=True, ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [31], line 7
#       4     avgPoints.index = avgPoints.index + 1
#       6 avgPoints.sort_values(by='AvgPoints', inplace=True, ascending=False)
# ----> 7 avgPoints.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# not a great way of doing this per race - plenty of repeated code!
#redBull = raceResults.loc[raceResults['Car'] == 'Red Bull Racing RBPT']
#redBull.head()

# %%
#redBull['PTS'].mean()

# %%
#ferrari = raceResults.loc[raceResults['Car'] == 'Ferrari']
#ferrari.head()

# %%
#ferrari['PTS'].mean()

# %%
avgPointsPlot = sns.barplot(data=avgPoints, x='Team', y='AvgPoints')
avgPointsPlot.set_xticklabels(avgPointsPlot.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Red Bull Racing RBPT'),
#  Text(1, 0, 'Ferrari'),
#  Text(2, 0, 'Mercedes'),
#  Text(3, 0, 'Alpine Renault'),
#  Text(4, 0, 'McLaren Mercedes'),
#  Text(5, 0, 'Aston Martin Aramco Mercedes'),
#  Text(6, 0, 'Alfa Romeo Ferrari'),
#  Text(7, 0, 'AlphaTauri RBPT'),
#  Text(8, 0, 'Haas Ferrari'),
#  Text(9, 0, 'Williams Mercedes')]

# %% [markdown]
# # Standard Deviation

# %%
deviation = pd.DataFrame()
deviation = deviation.assign(Team = '', Deviation = '')
deviation.head()
# Out:
# Empty DataFrame
# Columns: [Team, Deviation]
# Index: []

# %%
for i in teamNameArray:
    testRes = round(raceResults.loc[raceResults['Car'] == i]['PTS'].std(), 2)
    deviation.loc[-1] = [i, testRes]
    deviation.index = deviation.index + 1

# %% [markdown]
# # Fastest lap - average speed

# %%
fastestLap = pd.read_csv('data/compiled-data/fastest-laps.csv')
fastestLap.head()
# Out:
#    NO           DRIVER                   CAR     RACE    FL  AVG_SPEED
# 0  16  Charles Leclerc               Ferrari  BAHRAIN  94.6    206.018
# 1   1   Max Verstappen  Red Bull Racing RBPT  BAHRAIN  95.4    204.140
# 2  55     Carlos Sainz               Ferrari  BAHRAIN  95.7    203.501
# 3  11     Sergio Perez  Red Bull Racing RBPT  BAHRAIN  96.1    202.762
# 4  44   Lewis Hamilton              Mercedes  BAHRAIN  96.2    202.469

# %%
avgFastestLap = pd.DataFrame()
avgFastestLap = avgFastestLap.assign(Driver = '', AvgFastestLap = '')
avgFastestLap.head()
# Out:
# Empty DataFrame
# Columns: [Driver, AvgFastestLap]
# Index: []

# %%
for i in driverNameArray:
    testRes = round(fastestLap.loc[fastestLap['DRIVER'] == i]['FL'].mean(), 2)
    avgFastestLap.loc[-1] = [i, testRes]
    avgFastestLap.index = avgFastestLap.index + 1

avgFastestLap.sort_values(by='AvgFastestLap', inplace=True, ascending=True)

# %%
avgSpeedPlot = sns.barplot(x='Driver', y='AvgFastestLap', data=avgFastestLap)
avgSpeedPlot.set_xticklabels(avgSpeedPlot.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Lewis Hamilton'),
#  Text(1, 0, 'Carlos Sainz'),
#  Text(2, 0, 'Max Verstappen'),
#  Text(3, 0, 'Charles Leclerc'),
#  Text(4, 0, 'George Russell'),
#  Text(5, 0, 'Sergio Perez'),
#  Text(6, 0, 'Valtteri Bottas'),
#  Text(7, 0, 'Lando Norris'),
#  Text(8, 0, 'Sebastian Vettel'),
#  Text(9, 0, 'Lance Stroll'),
#  Text(10, 0, 'Alexander Albon'),
#  Text(11, 0, 'Mick Schumacher'),
#  Text(12, 0, 'Pierre Gasly'),
#  Text(13, 0, 'Yuki Tsunoda'),
#  Text(14, 0, 'Esteban Ocon'),
#  Text(15, 0, 'Zhou Guanyu'),
#  Text(16, 0, 'Fernando Alonso'),
#  Text(17, 0, 'Daniel Ricciardo'),
#  Text(18, 0, 'Nicholas Latifi'),
#  Text(19, 0, 'Kevin Magnussen')]

# %%
avgFastestLapTeam = pd.DataFrame()
avgFastestLapTeam = avgFastestLapTeam.assign(Team = '', AvgFastestLap = '')
avgFastestLapTeam.head()
# Out:
# Empty DataFrame
# Columns: [Team, AvgFastestLap]
# Index: []

# %%
for i in teamNameArray:
    testRes = round(fastestLap.loc[fastestLap['CAR'] == i]['FL'].mean(), 2)
    avgFastestLapTeam.loc[-1] = [i, testRes]
    avgFastestLapTeam.index = avgFastestLapTeam.index + 1

avgFastestLapTeam.sort_values(by='AvgFastestLap', inplace=True, ascending=True)

# %%
avgFastestLapPlotTeam = sns.barplot(x='Team', y='AvgFastestLap', data=avgFastestLapTeam)
avgFastestLapPlotTeam.set_xticklabels(avgFastestLapPlotTeam.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Mercedes'),
#  Text(1, 0, 'Ferrari'),
#  Text(2, 0, 'Red Bull Racing RBPT'),
#  Text(3, 0, 'Alfa Romeo Ferrari'),
#  Text(4, 0, 'Aston Martin Aramco Mercedes'),
#  Text(5, 0, 'McLaren Mercedes'),
#  Text(6, 0, 'AlphaTauri RBPT'),
#  Text(7, 0, 'Alpine Renault'),
#  Text(8, 0, 'Williams Mercedes'),
#  Text(9, 0, 'Haas Ferrari')]

# %%
avgSpeedTeam = pd.DataFrame()
avgSpeedTeam = avgSpeedTeam.assign(Team = '', AvgSpeed = '')
avgSpeedTeam.head()
# Out:
# Empty DataFrame
# Columns: [Team, AvgSpeed]
# Index: []

# %%
for i in teamNameArray:
    testRes = round(fastestLap.loc[fastestLap['CAR'] == i]['AVG_SPEED'].mean(), 2)
    avgSpeedTeam.loc[-1] = [i, testRes]
    avgSpeedTeam.index = avgSpeedTeam.index + 1

avgSpeedTeam.sort_values(by='AvgSpeed', inplace=True, ascending=False)

# %%
avgSpeedPlotTeam = sns.barplot(x='Team', y='AvgSpeed', data=avgSpeedTeam)
avgSpeedPlotTeam.set_xticklabels(avgSpeedPlotTeam.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'Red Bull Racing RBPT'),
#  Text(1, 0, 'Ferrari'),
#  Text(2, 0, 'Mercedes'),
#  Text(3, 0, 'McLaren Mercedes'),
#  Text(4, 0, 'Aston Martin Aramco Mercedes'),
#  Text(5, 0, 'Alpine Renault'),
#  Text(6, 0, 'Alfa Romeo Ferrari'),
#  Text(7, 0, 'Haas Ferrari'),
#  Text(8, 0, 'Williams Mercedes'),
#  Text(9, 0, 'AlphaTauri RBPT')]

# %% [markdown]
# # Linear Regression

# %%
df1 = avgFastestLapTeam
df2 = avgSpeedTeam

mergedDf = pd.merge(df1, df2, on="Team", how="inner")

# %%
# you may need to view this in an image browser
# you can view this in data/compiled-data/plots/linearRegressionFastestLap.png
linearRegFl = sns.lmplot(data=mergedDf, x='AvgFastestLap', y='AvgSpeed')
